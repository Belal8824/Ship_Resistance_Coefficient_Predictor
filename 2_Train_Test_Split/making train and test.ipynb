# %% [markdown]
# THIS FILE IS TO MAKE TRAIN AND TEST FILES THE TRAIN DATA IS WITHOUT MODEL NUMBERS 4211 4213, WHILE THE TEST DATA ONLY ABOUT THESE TWO MODELS FOR REALISTIC TEST FOR THE MODEL ACCURACY

# %%
import pandas as pd

# %% [markdown]
# Importing the big data file which contains all the additions and used in the training and testing for the ' model predictor 2 '

# %%
df = pd.read_csv('Series60_with_stratify_column.csv')

# %%
test_models = [4211, 4213]
df_train = df[~df['Model_Number'].isin(test_models)].reset_index(drop= True)
df_test = df[df['Model_Number'].isin(test_models)].reset_index(drop= True)

# %%
df_train

# %%
df_test

# %%
df_train.to_csv('Series60_train_3.csv', index= False)
df_test.to_csv('Series60_test_3.csv', index= False)
